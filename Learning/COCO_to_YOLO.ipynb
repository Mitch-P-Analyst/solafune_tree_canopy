# %% [markdown]
# ## Unpackage Json to COCO Formatt

# %%
import json

# input and output paths
# (change as needed based on your project folder structure)
input_path = 'data/train_annotations.json'
output_path = 'data/train_annotations_coco.json'

# read train annotations data
with open(input_path) as f:
    train_annotations = json.load(f)

# initialize COCO data structure
coco_data = {
    "images": [],
    "annotations": [],
    "categories": [
        {"id": 1, "name": "individual_tree", "supercategory": "tree"},
        {"id": 2, "name": "group_of_trees", "supercategory": "tree"},
    ]
}

# category mapping
category_map = {
    "individual_tree": 1,
    "group_of_trees": 2
}

# initialize annotation and image ID counters
annotation_id = 1
image_id = 1

# for each image...
for image in train_annotations["images"]:
    
    # add image metadata
    coco_data["images"].append(
        {
            "id": image_id,
            "file_name": image["file_name"],
            "width": image["width"],
            "height": image["height"]
        }
    )

    # for each annotation in this image
    for ann in image.get("annotations", []):
        # extract segmentation polygon
        segmentation = ann["segmentation"]

        # skip if fewer than 3 points (expected to cause errors later)
        if len(segmentation) < 6:
            continue

        # append annotation
        coco_data["annotations"].append(
            {
                "id": annotation_id,                                    # annotation ID
                "image_id": image_id,                                   # image ID
                "category_id": category_map[ann["class"]],              # category ID
                "segmentation": [segmentation],                         # segmentation polygon
                "area": 0,                                              # area (not used but setting anyway)
                "bbox": [                                               # bounding box
                    min(segmentation[::2]),                             # ... x
                    min(segmentation[1::2]),                            # ... y
                    max(segmentation[::2]) - min(segmentation[::2]),    # ... w
                    max(segmentation[1::2]) - min(segmentation[1::2])   # ... h
                ],
                "iscrowd": 0,                                           # is-crowded (not used but setting anyway)
                "score": ann.get("confidence_score", 1.0)               # confidence score (nonsense for ground-truth but setting anyway)
            }
        )

        # increment annotation ID counter
        annotation_id += 1

    # increment image ID counter
    image_id += 1

# save output
with open(output_path, "w") as f:
    json.dump(coco_data, f, indent=2)

# %% [markdown]
# ## Unpackage COCO Json to labels

# %%
#!/ucd
#sr/bin/env python3
import os, json, sys
from collections import defaultdict

# ---- CONFIG (edit paths if different) ----
input_json = os.path.join("data", "train_annotations_coco.json")
ROOT = os.path.join("data", "model-data")  # contains train/ valid/ test/
SPLITS = ["train", "valid", "test"]        # change if you only use some

# %%
with open(input_json) as f:
    COCO_JSON = json.load(f)

COCO_JSON
# Out:
# {'images': [{'id': 1,
#    'file_name': '10cm_train_1.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 2, 'file_name': '10cm_train_10.tif', 'width': 1024, 'height': 1024},
#   {'id': 3, 'file_name': '10cm_train_11.tif', 'width': 1024, 'height': 1024},
#   {'id': 4, 'file_name': '10cm_train_12.tif', 'width': 1024, 'height': 1024},
#   {'id': 5, 'file_name': '10cm_train_13.tif', 'width': 1024, 'height': 1024},
#   {'id': 6, 'file_name': '10cm_train_14.tif', 'width': 1024, 'height': 1024},
#   {'id': 7, 'file_name': '10cm_train_15.tif', 'width': 1024, 'height': 1024},
#   {'id': 8, 'file_name': '10cm_train_16.tif', 'width': 1024, 'height': 1024},
#   {'id': 9, 'file_name': '10cm_train_17.tif', 'width': 1024, 'height': 1024},
#   {'id': 10, 'file_name': '10cm_train_18.tif', 'width': 1024, 'height': 1024},
#   {'id': 11, 'file_name': '10cm_train_19.tif', 'width': 1024, 'height': 1024},
#   {'id': 12, 'file_name': '10cm_train_2.tif', 'width': 1024, 'height': 1024},
#   {'id': 13, 'file_name': '10cm_train_20.tif', 'width': 1024, 'height': 1024},
#   {'id': 14, 'file_name': '10cm_train_21.tif', 'width': 1024, 'height': 1024},
#   {'id': 15, 'file_name': '10cm_train_22.tif', 'width': 1024, 'height': 1024},
#   {'id': 16, 'file_name': '10cm_train_23.tif', 'width': 1024, 'height': 1024},
#   {'id': 17, 'file_name': '10cm_train_24.tif', 'width': 1024, 'height': 1024},
#   {'id': 18, 'file_name': '10cm_train_25.tif', 'width': 1024, 'height': 1024},
#   {'id': 19, 'file_name': '10cm_train_26.tif', 'width': 1024, 'height': 1024},
#   {'id': 20, 'file_name': '10cm_train_27.tif', 'width': 1024, 'height': 1024},
#   {'id': 21, 'file_name': '10cm_train_28.tif', 'width': 1024, 'height': 1024},
#   {'id': 22, 'file_name': '10cm_train_29.tif', 'width': 1024, 'height': 1024},
#   {'id': 23, 'file_name': '10cm_train_3.tif', 'width': 1024, 'height': 1024},
#   {'id': 24, 'file_name': '10cm_train_30.tif', 'width': 1024, 'height': 1024},
#   {'id': 25, 'file_name': '10cm_train_31.tif', 'width': 1024, 'height': 1024},
#   {'id': 26, 'file_name': '10cm_train_32.tif', 'width': 1024, 'height': 1024},
#   {'id': 27, 'file_name': '10cm_train_33.tif', 'width': 1024, 'height': 1024},
#   {'id': 28, 'file_name': '10cm_train_34.tif', 'width': 1024, 'height': 1024},
#   {'id': 29, 'file_name': '10cm_train_35.tif', 'width': 1024, 'height': 1024},
#   {'id': 30, 'file_name': '10cm_train_36.tif', 'width': 1024, 'height': 1024},
#   {'id': 31, 'file_name': '10cm_train_37.tif', 'width': 1024, 'height': 1024},
#   {'id': 32, 'file_name': '10cm_train_4.tif', 'width': 1024, 'height': 1024},
#   {'id': 33, 'file_name': '10cm_train_5.tif', 'width': 1024, 'height': 1024},
#   {'id': 34, 'file_name': '10cm_train_6.tif', 'width': 1024, 'height': 1024},
#   {'id': 35, 'file_name': '10cm_train_7.tif', 'width': 1024, 'height': 1024},
#   {'id': 36, 'file_name': '10cm_train_8.tif', 'width': 1024, 'height': 1024},
#   {'id': 37, 'file_name': '10cm_train_9.tif', 'width': 1024, 'height': 1024},
#   {'id': 38, 'file_name': '20cm_train_38.tif', 'width': 1024, 'height': 1024},
#   {'id': 39, 'file_name': '20cm_train_39.tif', 'width': 1024, 'height': 1024},
#   {'id': 40, 'file_name': '20cm_train_40.tif', 'width': 1024, 'height': 1024},
#   {'id': 41, 'file_name': '20cm_train_41.tif', 'width': 1024, 'height': 1024},
#   {'id': 42, 'file_name': '20cm_train_42.tif', 'width': 1024, 'height': 1024},
#   {'id': 43, 'file_name': '20cm_train_43.tif', 'width': 1024, 'height': 1024},
#   {'id': 44, 'file_name': '20cm_train_44.tif', 'width': 1024, 'height': 1024},
#   {'id': 45, 'file_name': '20cm_train_45.tif', 'width': 1024, 'height': 1024},
#   {'id': 46, 'file_name': '20cm_train_46.tif', 'width': 1024, 'height': 1024},
#   {'id': 47, 'file_name': '20cm_train_47.tif', 'width': 1024, 'height': 1024},
#   {'id': 48, 'file_name': '20cm_train_48.tif', 'width': 1024, 'height': 1024},
#   {'id': 49, 'file_name': '20cm_train_49.tif', 'width': 1024, 'height': 1024},
#   {'id': 50, 'file_name': '20cm_train_50.tif', 'width': 1024, 'height': 1024},
#   {'id': 51, 'file_name': '20cm_train_51.tif', 'width': 1024, 'height': 1024},
#   {'id': 52, 'file_name': '20cm_train_52.tif', 'width': 1024, 'height': 1024},
#   {'id': 53, 'file_name': '20cm_train_53.tif', 'width': 1024, 'height': 1024},
#   {'id': 54, 'file_name': '20cm_train_54.tif', 'width': 1024, 'height': 1024},
#   {'id': 55, 'file_name': '20cm_train_55.tif', 'width': 1024, 'height': 1024},
#   {'id': 56, 'file_name': '20cm_train_56.tif', 'width': 1024, 'height': 1024},
#   {'id': 57, 'file_name': '20cm_train_57.tif', 'width': 1024, 'height': 1024},
#   {'id': 58, 'file_name': '20cm_train_58.tif', 'width': 1024, 'height': 1024},
#   {'id': 59, 'file_name': '20cm_train_59.tif', 'width': 1024, 'height': 1024},
#   {'id': 60, 'file_name': '20cm_train_60.tif', 'width': 1024, 'height': 1024},
#   {'id': 61, 'file_name': '20cm_train_61.tif', 'width': 1024, 'height': 1024},
#   {'id': 62, 'file_name': '20cm_train_62.tif', 'width': 1024, 'height': 1024},
#   {'id': 63, 'file_name': '20cm_train_63.tif', 'width': 1024, 'height': 1024},
#   {'id': 64, 'file_name': '20cm_train_64.tif', 'width': 1024, 'height': 1024},
#   {'id': 65, 'file_name': '20cm_train_65.tif', 'width': 1024, 'height': 1024},
#   {'id': 66, 'file_name': '20cm_train_66.tif', 'width': 1024, 'height': 1024},
#   {'id': 67, 'file_name': '20cm_train_67.tif', 'width': 1024, 'height': 1024},
#   {'id': 68, 'file_name': '20cm_train_68.tif', 'width': 1024, 'height': 1024},
#   {'id': 69, 'file_name': '20cm_train_69.tif', 'width': 1024, 'height': 1024},
#   {'id': 70, 'file_name': '20cm_train_70.tif', 'width': 1024, 'height': 1024},
#   {'id': 71, 'file_name': '20cm_train_71.tif', 'width': 1024, 'height': 1024},
#   {'id': 72, 'file_name': '20cm_train_72.tif', 'width': 1024, 'height': 1024},
#   {'id': 73, 'file_name': '20cm_train_73.tif', 'width': 1024, 'height': 1024},
#   {'id': 74, 'file_name': '20cm_train_74.tif', 'width': 1024, 'height': 1024},
#   {'id': 75, 'file_name': '20cm_train_75.tif', 'width': 1024, 'height': 1024},
#   {'id': 76, 'file_name': '40cm_train_100.tif', 'width': 1024, 'height': 1024},
#   {'id': 77, 'file_name': '40cm_train_76.tif', 'width': 1024, 'height': 1024},
#   {'id': 78, 'file_name': '40cm_train_77.tif', 'width': 1024, 'height': 1024},
#   {'id': 79, 'file_name': '40cm_train_78.tif', 'width': 1024, 'height': 1024},
#   {'id': 80, 'file_name': '40cm_train_79.tif', 'width': 1024, 'height': 1024},
#   {'id': 81, 'file_name': '40cm_train_80.tif', 'width': 1024, 'height': 1024},
#   {'id': 82, 'file_name': '40cm_train_81.tif', 'width': 1024, 'height': 1024},
#   {'id': 83, 'file_name': '40cm_train_82.tif', 'width': 1024, 'height': 1024},
#   {'id': 84, 'file_name': '40cm_train_83.tif', 'width': 1024, 'height': 1024},
#   {'id': 85, 'file_name': '40cm_train_84.tif', 'width': 1024, 'height': 1024},
#   {'id': 86, 'file_name': '40cm_train_85.tif', 'width': 1024, 'height': 1024},
#   {'id': 87, 'file_name': '40cm_train_86.tif', 'width': 1024, 'height': 1024},
#   {'id': 88, 'file_name': '40cm_train_87.tif', 'width': 1024, 'height': 1024},
#   {'id': 89, 'file_name': '40cm_train_88.tif', 'width': 1024, 'height': 1024},
#   {'id': 90, 'file_name': '40cm_train_89.tif', 'width': 1024, 'height': 1024},
#   {'id': 91, 'file_name': '40cm_train_90.tif', 'width': 1024, 'height': 1024},
#   {'id': 92, 'file_name': '40cm_train_91.tif', 'width': 1024, 'height': 1024},
#   {'id': 93, 'file_name': '40cm_train_92.tif', 'width': 1024, 'height': 1024},
#   {'id': 94, 'file_name': '40cm_train_93.tif', 'width': 1024, 'height': 1024},
#   {'id': 95, 'file_name': '40cm_train_94.tif', 'width': 1024, 'height': 1024},
#   {'id': 96, 'file_name': '40cm_train_95.tif', 'width': 1024, 'height': 1024},
#   {'id': 97, 'file_name': '40cm_train_96.tif', 'width': 1024, 'height': 1024},
#   {'id': 98, 'file_name': '40cm_train_97.tif', 'width': 1024, 'height': 1024},
#   {'id': 99, 'file_name': '40cm_train_98.tif', 'width': 1024, 'height': 1024},
#   {'id': 100, 'file_name': '40cm_train_99.tif', 'width': 1024, 'height': 1024},
#   {'id': 101,
#    'file_name': '60cm_train_101.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 102,
#    'file_name': '60cm_train_102.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 103,
#    'file_name': '60cm_train_103.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 104,
#    'file_name': '60cm_train_104.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 105,
#    'file_name': '60cm_train_105.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 106,
#    'file_name': '60cm_train_106.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 107,
#    'file_name': '60cm_train_107.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 108,
#    'file_name': '60cm_train_108.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 109,
#    'file_name': '60cm_train_109.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 110,
#    'file_name': '60cm_train_110.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 111,
#    'file_name': '60cm_train_111.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 112,
#    'file_name': '60cm_train_112.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 113,
#    'file_name': '60cm_train_113.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 114,
#    'file_name': '60cm_train_114.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 115,
#    'file_name': '60cm_train_115.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 116,
#    'file_name': '60cm_train_116.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 117,
#    'file_name': '60cm_train_117.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 118,
#    'file_name': '60cm_train_118.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 119,
#    'file_name': '60cm_train_119.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 120,
#    'file_name': '60cm_train_120.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 121,
#    'file_name': '60cm_train_121.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 122,
#    'file_name': '60cm_train_122.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 123,
#    'file_name': '60cm_train_123.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 124,
#    'file_name': '60cm_train_124.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 125,
#    'file_name': '60cm_train_125.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 126,
#    'file_name': '80cm_train_126.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 127,
#    'file_name': '80cm_train_127.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 128,
#    'file_name': '80cm_train_128.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 129,
#    'file_name': '80cm_train_129.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 130,
#    'file_name': '80cm_train_130.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 131,
#    'file_name': '80cm_train_131.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 132,
#    'file_name': '80cm_train_132.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 133,
#    'file_name': '80cm_train_133.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 134,
#    'file_name': '80cm_train_134.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 135,
#    'file_name': '80cm_train_135.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 136,
#    'file_name': '80cm_train_136.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 137,
#    'file_name': '80cm_train_137.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 138,
#    'file_name': '80cm_train_138.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 139,
#    'file_name': '80cm_train_139.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 140,
#    'file_name': '80cm_train_140.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 141,
#    'file_name': '80cm_train_141.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 142,
#    'file_name': '80cm_train_142.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 143,
#    'file_name': '80cm_train_143.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 144,
#    'file_name': '80cm_train_144.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 145,
#    'file_name': '80cm_train_145.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 146,
#    'file_name': '80cm_train_146.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 147,
#    'file_name': '80cm_train_147.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 148,
#    'file_name': '80cm_train_148.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 149,
#    'file_name': '80cm_train_149.tif',
#    'width': 1024,
#    'height': 1024},
#   {'id': 150,
#    'file_name': '80cm_train_150.tif',
#    'width': 1024,
#    'height': 1024}],
#  'annotations': [{'id': 1,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[4.0,
#      146.0,
#      18.0,
#      149.0,
#      17.0,
#      160.0,
#      6.0,
#      162.0,
#      0.0,
#      152.0]],
#    'area': 0,
#    'bbox': [0.0, 146.0, 18.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 2,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[29.0,
#      158.0,
#      31.0,
#      166.0,
#      22.0,
#      172.0,
#      16.0,
#      164.0,
#      22.0,
#      156.0]],
#    'area': 0,
#    'bbox': [16.0, 156.0, 15.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 3,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[42.0,
#      176.0,
#      55.0,
#      180.0,
#      61.0,
#      191.0,
#      48.0,
#      197.0,
#      37.0,
#      186.0]],
#    'area': 0,
#    'bbox': [37.0, 176.0, 24.0, 21.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 4,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[56.0, 194.0, 63.0, 197.0, 60.0, 205.0, 49.0, 201.0]],
#    'area': 0,
#    'bbox': [49.0, 194.0, 14.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 5,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[70.0,
#      197.0,
#      75.0,
#      207.0,
#      74.0,
#      211.0,
#      58.0,
#      212.0,
#      60.0,
#      203.0]],
#    'area': 0,
#    'bbox': [58.0, 197.0, 17.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 6,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[82.0, 202.0, 88.0, 207.0, 84.0, 212.0, 77.0, 208.0]],
#    'area': 0,
#    'bbox': [77.0, 202.0, 11.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 7,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[90.0, 205.0, 99.0, 213.0, 95.0, 218.0, 85.0, 214.0]],
#    'area': 0,
#    'bbox': [85.0, 205.0, 14.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 8,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[92.0,
#      220.0,
#      100.0,
#      221.0,
#      100.0,
#      233.0,
#      89.0,
#      240.0,
#      89.0,
#      240.0,
#      86.0,
#      227.0]],
#    'area': 0,
#    'bbox': [86.0, 220.0, 14.0, 20.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 9,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[116.0,
#      233.0,
#      120.0,
#      241.0,
#      111.0,
#      250.0,
#      104.0,
#      250.0,
#      102.0,
#      242.0]],
#    'area': 0,
#    'bbox': [102.0, 233.0, 18.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 10,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[122.0, 241.0, 128.0, 250.0, 122.0, 256.0, 116.0, 249.0]],
#    'area': 0,
#    'bbox': [116.0, 241.0, 12.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 11,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[114.0,
#      255.0,
#      121.0,
#      256.0,
#      120.0,
#      263.0,
#      112.0,
#      265.0,
#      108.0,
#      259.0]],
#    'area': 0,
#    'bbox': [108.0, 255.0, 13.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 12,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[47.0,
#      112.0,
#      56.0,
#      125.0,
#      46.0,
#      132.0,
#      38.0,
#      131.0,
#      35.0,
#      121.0]],
#    'area': 0,
#    'bbox': [35.0, 112.0, 21.0, 20.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 13,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[56.0,
#      125.0,
#      63.0,
#      128.0,
#      64.0,
#      136.0,
#      57.0,
#      143.0,
#      47.0,
#      139.0]],
#    'area': 0,
#    'bbox': [47.0, 125.0, 17.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 14,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[64.0,
#      137.0,
#      72.0,
#      138.0,
#      71.0,
#      153.0,
#      64.0,
#      156.0,
#      57.0,
#      148.0]],
#    'area': 0,
#    'bbox': [57.0, 137.0, 15.0, 19.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 15,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[74.0,
#      156.0,
#      83.0,
#      156.0,
#      84.0,
#      166.0,
#      76.0,
#      167.0,
#      71.0,
#      161.0]],
#    'area': 0,
#    'bbox': [71.0, 156.0, 13.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 16,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[83.0,
#      162.0,
#      89.0,
#      166.0,
#      89.0,
#      175.0,
#      83.0,
#      176.0,
#      79.0,
#      169.0]],
#    'area': 0,
#    'bbox': [79.0, 162.0, 10.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 17,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[92.0,
#      170.0,
#      98.0,
#      170.0,
#      101.0,
#      176.0,
#      94.0,
#      181.0,
#      88.0,
#      178.0]],
#    'area': 0,
#    'bbox': [88.0, 170.0, 13.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 18,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[101.0,
#      178.0,
#      107.0,
#      180.0,
#      107.0,
#      189.0,
#      100.0,
#      190.0,
#      96.0,
#      182.0]],
#    'area': 0,
#    'bbox': [96.0, 178.0, 11.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 19,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[112.0,
#      186.0,
#      123.0,
#      191.0,
#      123.0,
#      198.0,
#      111.0,
#      201.0,
#      107.0,
#      195.0]],
#    'area': 0,
#    'bbox': [107.0, 186.0, 16.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 20,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[124.0,
#      198.0,
#      128.0,
#      201.0,
#      125.0,
#      213.0,
#      114.0,
#      207.0,
#      114.0,
#      201.0]],
#    'area': 0,
#    'bbox': [114.0, 198.0, 14.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 21,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[137.0,
#      203.0,
#      140.0,
#      213.0,
#      135.0,
#      224.0,
#      128.0,
#      223.0,
#      127.0,
#      212.0,
#      133.0,
#      207.0]],
#    'area': 0,
#    'bbox': [127.0, 203.0, 13.0, 21.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 22,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[62.0, 80.0, 65.0, 89.0, 56.0, 92.0, 53.0, 82.0]],
#    'area': 0,
#    'bbox': [53.0, 80.0, 12.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 23,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[81.0,
#      101.0,
#      90.0,
#      101.0,
#      89.0,
#      110.0,
#      82.0,
#      115.0,
#      73.0,
#      113.0,
#      70.0,
#      106.0]],
#    'area': 0,
#    'bbox': [70.0, 101.0, 20.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 24,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[95.0,
#      112.0,
#      98.0,
#      121.0,
#      92.0,
#      127.0,
#      83.0,
#      124.0,
#      85.0,
#      115.0]],
#    'area': 0,
#    'bbox': [83.0, 112.0, 15.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 25,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[110.0,
#      116.0,
#      114.0,
#      127.0,
#      109.0,
#      135.0,
#      98.0,
#      135.0,
#      97.0,
#      121.0]],
#    'area': 0,
#    'bbox': [97.0, 116.0, 17.0, 19.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 26,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[116.0,
#      130.0,
#      124.0,
#      133.0,
#      130.0,
#      143.0,
#      125.0,
#      152.0,
#      112.0,
#      147.0,
#      109.0,
#      136.0]],
#    'area': 0,
#    'bbox': [109.0, 130.0, 21.0, 22.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 27,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[139.0,
#      153.0,
#      145.0,
#      158.0,
#      140.0,
#      167.0,
#      140.0,
#      167.0,
#      131.0,
#      165.0,
#      126.0,
#      155.0]],
#    'area': 0,
#    'bbox': [126.0, 153.0, 19.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 28,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[145.0, 160.0, 155.0, 164.0, 149.0, 176.0, 141.0, 170.0]],
#    'area': 0,
#    'bbox': [141.0, 160.0, 14.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 29,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[152.0,
#      170.0,
#      162.0,
#      173.0,
#      163.0,
#      180.0,
#      163.0,
#      189.0,
#      163.0,
#      189.0,
#      148.0,
#      182.0]],
#    'area': 0,
#    'bbox': [148.0, 170.0, 15.0, 19.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 30,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[165.0,
#      179.0,
#      173.0,
#      180.0,
#      179.0,
#      190.0,
#      176.0,
#      197.0,
#      165.0,
#      192.0]],
#    'area': 0,
#    'bbox': [165.0, 179.0, 14.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 31,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[178.0,
#      192.0,
#      188.0,
#      190.0,
#      189.0,
#      199.0,
#      189.0,
#      199.0,
#      184.0,
#      208.0,
#      184.0,
#      208.0,
#      174.0,
#      204.0]],
#    'area': 0,
#    'bbox': [174.0, 190.0, 15.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 32,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[189.0,
#      205.0,
#      200.0,
#      205.0,
#      203.0,
#      217.0,
#      194.0,
#      220.0,
#      188.0,
#      213.0]],
#    'area': 0,
#    'bbox': [188.0, 205.0, 15.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 33,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[95.0,
#      63.0,
#      102.0,
#      61.0,
#      104.0,
#      69.0,
#      96.0,
#      79.0,
#      90.0,
#      69.0]],
#    'area': 0,
#    'bbox': [90.0, 61.0, 14.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 34,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[106.0,
#      70.0,
#      116.0,
#      72.0,
#      115.0,
#      82.0,
#      107.0,
#      88.0,
#      103.0,
#      77.0]],
#    'area': 0,
#    'bbox': [103.0, 70.0, 13.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 35,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[125.0, 79.0, 130.0, 91.0, 122.0, 101.0, 116.0, 93.0]],
#    'area': 0,
#    'bbox': [116.0, 79.0, 14.0, 22.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 36,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[133.0, 94.0, 138.0, 92.0, 141.0, 100.0, 135.0, 103.0]],
#    'area': 0,
#    'bbox': [133.0, 92.0, 8.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 37,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[142.0, 107.0, 150.0, 102.0, 151.0, 112.0, 142.0, 115.0]],
#    'area': 0,
#    'bbox': [142.0, 102.0, 9.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 38,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[155.0, 112.0, 162.0, 114.0, 160.0, 122.0, 152.0, 121.0]],
#    'area': 0,
#    'bbox': [152.0, 112.0, 10.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 39,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[159.0,
#      128.0,
#      163.0,
#      127.0,
#      169.0,
#      132.0,
#      165.0,
#      138.0,
#      158.0,
#      135.0]],
#    'area': 0,
#    'bbox': [158.0, 127.0, 11.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 40,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[173.0,
#      133.0,
#      182.0,
#      132.0,
#      189.0,
#      135.0,
#      188.0,
#      147.0,
#      178.0,
#      152.0,
#      171.0,
#      145.0]],
#    'area': 0,
#    'bbox': [171.0, 132.0, 18.0, 20.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 41,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[193.0,
#      147.0,
#      198.0,
#      151.0,
#      197.0,
#      161.0,
#      187.0,
#      166.0,
#      181.0,
#      156.0]],
#    'area': 0,
#    'bbox': [181.0, 147.0, 17.0, 19.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 42,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[197.0, 164.0, 204.0, 163.0, 204.0, 171.0, 197.0, 171.0]],
#    'area': 0,
#    'bbox': [197.0, 163.0, 7.0, 8.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 43,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[221.0, 169.0, 221.0, 178.0, 209.0, 181.0, 207.0, 168.0]],
#    'area': 0,
#    'bbox': [207.0, 168.0, 14.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 44,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[222.0,
#      179.0,
#      227.0,
#      178.0,
#      229.0,
#      186.0,
#      223.0,
#      192.0,
#      216.0,
#      187.0]],
#    'area': 0,
#    'bbox': [216.0, 178.0, 13.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 45,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[231.0,
#      185.0,
#      237.0,
#      182.0,
#      239.0,
#      191.0,
#      237.0,
#      201.0,
#      228.0,
#      195.0]],
#    'area': 0,
#    'bbox': [228.0, 182.0, 11.0, 19.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 46,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[118.0, 36.0, 127.0, 33.0, 130.0, 45.0, 120.0, 46.0]],
#    'area': 0,
#    'bbox': [118.0, 33.0, 12.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 47,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[130.0,
#      41.0,
#      138.0,
#      41.0,
#      142.0,
#      49.0,
#      139.0,
#      57.0,
#      139.0,
#      57.0,
#      129.0,
#      54.0]],
#    'area': 0,
#    'bbox': [129.0, 41.0, 13.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 48,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[142.0, 57.0, 153.0, 54.0, 153.0, 62.0, 145.0, 66.0]],
#    'area': 0,
#    'bbox': [142.0, 54.0, 11.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 49,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[155.0,
#      63.0,
#      160.0,
#      68.0,
#      161.0,
#      77.0,
#      151.0,
#      76.0,
#      150.0,
#      67.0]],
#    'area': 0,
#    'bbox': [150.0, 63.0, 11.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 50,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[172.0, 77.0, 175.0, 86.0, 167.0, 87.0, 162.0, 79.0]],
#    'area': 0,
#    'bbox': [162.0, 77.0, 13.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 51,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[178.0, 84.0, 183.0, 86.0, 179.0, 94.0, 172.0, 89.0]],
#    'area': 0,
#    'bbox': [172.0, 84.0, 11.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 52,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[190.0,
#      90.0,
#      195.0,
#      95.0,
#      192.0,
#      107.0,
#      186.0,
#      106.0,
#      181.0,
#      98.0]],
#    'area': 0,
#    'bbox': [181.0, 90.0, 14.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 53,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[196.0,
#      101.0,
#      205.0,
#      102.0,
#      211.0,
#      111.0,
#      211.0,
#      111.0,
#      205.0,
#      120.0,
#      193.0,
#      112.0]],
#    'area': 0,
#    'bbox': [193.0, 101.0, 18.0, 19.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 54,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[207.0,
#      116.0,
#      214.0,
#      115.0,
#      223.0,
#      120.0,
#      223.0,
#      120.0,
#      218.0,
#      127.0,
#      208.0,
#      126.0]],
#    'area': 0,
#    'bbox': [207.0, 115.0, 16.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 55,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[221.0,
#      124.0,
#      231.0,
#      128.0,
#      227.0,
#      142.0,
#      227.0,
#      142.0,
#      217.0,
#      134.0]],
#    'area': 0,
#    'bbox': [217.0, 124.0, 14.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 56,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[234.0,
#      138.0,
#      240.0,
#      136.0,
#      245.0,
#      141.0,
#      245.0,
#      141.0,
#      239.0,
#      151.0,
#      230.0,
#      147.0]],
#    'area': 0,
#    'bbox': [230.0, 136.0, 15.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 57,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[252.0, 151.0, 257.0, 159.0, 253.0, 163.0, 245.0, 159.0]],
#    'area': 0,
#    'bbox': [245.0, 151.0, 12.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 58,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[257.0, 162.0, 262.0, 162.0, 263.0, 170.0, 255.0, 172.0]],
#    'area': 0,
#    'bbox': [255.0, 162.0, 8.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 59,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[273.0, 169.0, 279.0, 176.0, 271.0, 182.0, 266.0, 177.0]],
#    'area': 0,
#    'bbox': [266.0, 169.0, 13.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 60,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[277.0,
#      182.0,
#      284.0,
#      179.0,
#      286.0,
#      185.0,
#      286.0,
#      196.0,
#      277.0,
#      191.0]],
#    'area': 0,
#    'bbox': [277.0, 179.0, 9.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 61,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[140.0,
#      0.0,
#      143.0,
#      9.0,
#      151.0,
#      20.0,
#      155.0,
#      7.0,
#      147.0,
#      0.0]],
#    'area': 0,
#    'bbox': [140.0, 0.0, 15.0, 20.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 62,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[162.0,
#      10.0,
#      168.0,
#      17.0,
#      164.0,
#      27.0,
#      156.0,
#      23.0,
#      156.0,
#      14.0,
#      156.0,
#      14.0]],
#    'area': 0,
#    'bbox': [156.0, 10.0, 12.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 63,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[169.0,
#      23.0,
#      177.0,
#      26.0,
#      179.0,
#      33.0,
#      168.0,
#      37.0,
#      168.0,
#      37.0,
#      164.0,
#      31.0]],
#    'area': 0,
#    'bbox': [164.0, 23.0, 15.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 64,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[186.0,
#      35.0,
#      189.0,
#      40.0,
#      188.0,
#      48.0,
#      179.0,
#      45.0,
#      179.0,
#      36.0]],
#    'area': 0,
#    'bbox': [179.0, 35.0, 10.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 65,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[195.0,
#      45.0,
#      201.0,
#      46.0,
#      202.0,
#      55.0,
#      196.0,
#      58.0,
#      189.0,
#      51.0]],
#    'area': 0,
#    'bbox': [189.0, 45.0, 13.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 66,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[207.0,
#      56.0,
#      212.0,
#      60.0,
#      210.0,
#      67.0,
#      203.0,
#      66.0,
#      198.0,
#      57.0]],
#    'area': 0,
#    'bbox': [198.0, 56.0, 14.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 67,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[214.0,
#      65.0,
#      219.0,
#      68.0,
#      223.0,
#      77.0,
#      211.0,
#      79.0,
#      208.0,
#      71.0]],
#    'area': 0,
#    'bbox': [208.0, 65.0, 15.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 68,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[224.0,
#      75.0,
#      231.0,
#      80.0,
#      232.0,
#      89.0,
#      224.0,
#      89.0,
#      220.0,
#      83.0,
#      220.0,
#      83.0]],
#    'area': 0,
#    'bbox': [220.0, 75.0, 12.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 69,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[233.0,
#      84.0,
#      241.0,
#      85.0,
#      245.0,
#      95.0,
#      240.0,
#      100.0,
#      232.0,
#      94.0]],
#    'area': 0,
#    'bbox': [232.0, 84.0, 13.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 70,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[245.0,
#      95.0,
#      252.0,
#      95.0,
#      258.0,
#      101.0,
#      254.0,
#      108.0,
#      244.0,
#      105.0]],
#    'area': 0,
#    'bbox': [244.0, 95.0, 14.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 71,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[257.0,
#      106.0,
#      265.0,
#      108.0,
#      270.0,
#      119.0,
#      263.0,
#      123.0,
#      263.0,
#      123.0,
#      254.0,
#      118.0]],
#    'area': 0,
#    'bbox': [254.0, 106.0, 16.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 72,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[268.0,
#      118.0,
#      275.0,
#      120.0,
#      280.0,
#      129.0,
#      275.0,
#      133.0,
#      265.0,
#      126.0]],
#    'area': 0,
#    'bbox': [265.0, 118.0, 15.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 73,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[279.0,
#      128.0,
#      286.0,
#      129.0,
#      290.0,
#      139.0,
#      284.0,
#      145.0,
#      277.0,
#      139.0]],
#    'area': 0,
#    'bbox': [277.0, 128.0, 13.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 74,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[294.0,
#      140.0,
#      303.0,
#      142.0,
#      303.0,
#      148.0,
#      299.0,
#      156.0,
#      290.0,
#      147.0]],
#    'area': 0,
#    'bbox': [290.0, 140.0, 13.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 75,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[307.0, 149.0, 315.0, 158.0, 311.0, 164.0, 305.0, 159.0]],
#    'area': 0,
#    'bbox': [305.0, 149.0, 10.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 76,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[316.0, 158.0, 321.0, 164.0, 313.0, 166.0]],
#    'area': 0,
#    'bbox': [313.0, 158.0, 8.0, 8.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 77,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[201.0, 1.0, 205.0, 7.0, 213.0, 7.0, 211.0, 0.0]],
#    'area': 0,
#    'bbox': [201.0, 0.0, 12.0, 7.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 78,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[227.0,
#      12.0,
#      231.0,
#      20.0,
#      224.0,
#      29.0,
#      217.0,
#      25.0,
#      217.0,
#      16.0]],
#    'area': 0,
#    'bbox': [217.0, 12.0, 14.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 79,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[244.0, 36.0, 252.0, 41.0, 247.0, 50.0, 239.0, 44.0]],
#    'area': 0,
#    'bbox': [239.0, 36.0, 13.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 80,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[254.0,
#      46.0,
#      259.0,
#      50.0,
#      261.0,
#      56.0,
#      256.0,
#      62.0,
#      248.0,
#      56.0]],
#    'area': 0,
#    'bbox': [248.0, 46.0, 13.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 81,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[263.0,
#      59.0,
#      268.0,
#      58.0,
#      272.0,
#      62.0,
#      266.0,
#      72.0,
#      260.0,
#      67.0]],
#    'area': 0,
#    'bbox': [260.0, 58.0, 12.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 82,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[272.0,
#      70.0,
#      279.0,
#      71.0,
#      282.0,
#      80.0,
#      277.0,
#      82.0,
#      273.0,
#      77.0]],
#    'area': 0,
#    'bbox': [272.0, 70.0, 10.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 83,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[286.0,
#      82.0,
#      293.0,
#      82.0,
#      294.0,
#      92.0,
#      289.0,
#      94.0,
#      284.0,
#      89.0]],
#    'area': 0,
#    'bbox': [284.0, 82.0, 10.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 84,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[296.0, 91.0, 304.0, 92.0, 305.0, 100.0, 299.0, 101.0]],
#    'area': 0,
#    'bbox': [296.0, 91.0, 9.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 85,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[307.0,
#      99.0,
#      314.0,
#      98.0,
#      319.0,
#      109.0,
#      314.0,
#      115.0,
#      306.0,
#      110.0]],
#    'area': 0,
#    'bbox': [306.0, 98.0, 13.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 86,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[319.0,
#      118.0,
#      325.0,
#      112.0,
#      330.0,
#      116.0,
#      330.0,
#      123.0,
#      323.0,
#      127.0]],
#    'area': 0,
#    'bbox': [319.0, 112.0, 11.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 87,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[330.0,
#      126.0,
#      333.0,
#      123.0,
#      339.0,
#      123.0,
#      342.0,
#      129.0,
#      339.0,
#      136.0,
#      331.0,
#      132.0]],
#    'area': 0,
#    'bbox': [330.0, 123.0, 12.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 88,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[343.0,
#      134.0,
#      350.0,
#      137.0,
#      351.0,
#      144.0,
#      344.0,
#      147.0,
#      339.0,
#      142.0]],
#    'area': 0,
#    'bbox': [339.0, 134.0, 12.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 89,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[353.0, 140.0, 357.0, 142.0, 357.0, 150.0, 351.0, 150.0]],
#    'area': 0,
#    'bbox': [351.0, 140.0, 6.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 90,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[253.0, 0.0, 258.0, 10.0, 265.0, 1.0]],
#    'area': 0,
#    'bbox': [253.0, 0.0, 12.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 91,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[272.0,
#      5.0,
#      275.0,
#      9.0,
#      273.0,
#      18.0,
#      264.0,
#      20.0,
#      264.0,
#      9.0]],
#    'area': 0,
#    'bbox': [264.0, 5.0, 11.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 92,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[278.0,
#      15.0,
#      284.0,
#      18.0,
#      286.0,
#      25.0,
#      280.0,
#      28.0,
#      274.0,
#      22.0]],
#    'area': 0,
#    'bbox': [274.0, 15.0, 12.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 93,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[287.0,
#      28.0,
#      295.0,
#      27.0,
#      298.0,
#      34.0,
#      298.0,
#      34.0,
#      294.0,
#      40.0,
#      286.0,
#      38.0]],
#    'area': 0,
#    'bbox': [286.0, 27.0, 12.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 94,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[308.0,
#      32.0,
#      312.0,
#      37.0,
#      312.0,
#      47.0,
#      304.0,
#      48.0,
#      300.0,
#      40.0]],
#    'area': 0,
#    'bbox': [300.0, 32.0, 12.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 95,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[321.0, 48.0, 325.0, 56.0, 319.0, 61.0, 314.0, 55.0]],
#    'area': 0,
#    'bbox': [314.0, 48.0, 11.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 96,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[326.0,
#      63.0,
#      332.0,
#      64.0,
#      335.0,
#      70.0,
#      328.0,
#      75.0,
#      323.0,
#      69.0]],
#    'area': 0,
#    'bbox': [323.0, 63.0, 12.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 97,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[343.0,
#      69.0,
#      347.0,
#      80.0,
#      347.0,
#      80.0,
#      342.0,
#      87.0,
#      337.0,
#      80.0,
#      334.0,
#      71.0,
#      339.0,
#      66.0]],
#    'area': 0,
#    'bbox': [334.0, 66.0, 13.0, 21.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 98,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[350.0,
#      84.0,
#      353.0,
#      82.0,
#      358.0,
#      85.0,
#      353.0,
#      93.0,
#      346.0,
#      95.0,
#      345.0,
#      87.0]],
#    'area': 0,
#    'bbox': [345.0, 82.0, 13.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 99,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[366.0,
#      98.0,
#      373.0,
#      97.0,
#      377.0,
#      105.0,
#      373.0,
#      110.0,
#      365.0,
#      104.0]],
#    'area': 0,
#    'bbox': [365.0, 97.0, 12.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 100,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[384.0,
#      111.0,
#      389.0,
#      115.0,
#      389.0,
#      124.0,
#      382.0,
#      128.0,
#      382.0,
#      128.0,
#      378.0,
#      123.0]],
#    'area': 0,
#    'bbox': [378.0, 111.0, 11.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 101,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[395.0,
#      122.0,
#      400.0,
#      122.0,
#      400.0,
#      131.0,
#      396.0,
#      138.0,
#      392.0,
#      133.0]],
#    'area': 0,
#    'bbox': [392.0, 122.0, 8.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 102,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[400.0,
#      135.0,
#      413.0,
#      137.0,
#      413.0,
#      137.0,
#      411.0,
#      146.0,
#      404.0,
#      149.0,
#      398.0,
#      145.0]],
#    'area': 0,
#    'bbox': [398.0, 135.0, 15.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 103,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[320.0, 0.0, 328.0, 4.0, 327.0, 11.0, 319.0, 12.0]],
#    'area': 0,
#    'bbox': [319.0, 0.0, 9.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 104,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[333.0,
#      7.0,
#      340.0,
#      12.0,
#      340.0,
#      19.0,
#      337.0,
#      21.0,
#      333.0,
#      24.0,
#      330.0,
#      15.0]],
#    'area': 0,
#    'bbox': [330.0, 7.0, 10.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 105,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[346.0, 23.0, 349.0, 29.0, 343.0, 34.0, 340.0, 27.0]],
#    'area': 0,
#    'bbox': [340.0, 23.0, 9.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 106,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[353.0,
#      34.0,
#      361.0,
#      36.0,
#      360.0,
#      43.0,
#      356.0,
#      50.0,
#      351.0,
#      44.0]],
#    'area': 0,
#    'bbox': [351.0, 34.0, 10.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 107,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[371.0,
#      48.0,
#      377.0,
#      52.0,
#      377.0,
#      61.0,
#      368.0,
#      62.0,
#      367.0,
#      53.0]],
#    'area': 0,
#    'bbox': [367.0, 48.0, 10.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 108,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[388.0,
#      59.0,
#      391.0,
#      70.0,
#      385.0,
#      75.0,
#      378.0,
#      68.0,
#      375.0,
#      63.0,
#      380.0,
#      57.0]],
#    'area': 0,
#    'bbox': [375.0, 57.0, 16.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 109,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[412.0,
#      84.0,
#      415.0,
#      92.0,
#      410.0,
#      98.0,
#      405.0,
#      90.0,
#      406.0,
#      85.0]],
#    'area': 0,
#    'bbox': [405.0, 84.0, 10.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 110,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[419.0, 93.0, 425.0, 99.0, 419.0, 104.0, 414.0, 100.0]],
#    'area': 0,
#    'bbox': [414.0, 93.0, 11.0, 11.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 111,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[428.0,
#      102.0,
#      437.0,
#      109.0,
#      431.0,
#      118.0,
#      431.0,
#      118.0,
#      425.0,
#      112.0]],
#    'area': 0,
#    'bbox': [425.0, 102.0, 12.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 112,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[441.0,
#      116.0,
#      447.0,
#      118.0,
#      445.0,
#      125.0,
#      438.0,
#      129.0,
#      435.0,
#      123.0]],
#    'area': 0,
#    'bbox': [435.0, 116.0, 12.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 113,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[459.0, 133.0, 464.0, 139.0, 464.0, 148.0, 455.0, 144.0]],
#    'area': 0,
#    'bbox': [455.0, 133.0, 9.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 114,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[448.0, 126.0, 455.0, 128.0, 455.0, 136.0, 447.0, 133.0]],
#    'area': 0,
#    'bbox': [447.0, 126.0, 8.0, 10.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 115,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[142.0, 219.0, 156.0, 215.0, 156.0, 224.0, 145.0, 231.0]],
#    'area': 0,
#    'bbox': [142.0, 215.0, 14.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 116,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[159.0,
#      226.0,
#      165.0,
#      231.0,
#      161.0,
#      239.0,
#      161.0,
#      239.0,
#      150.0,
#      232.0]],
#    'area': 0,
#    'bbox': [150.0, 226.0, 15.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 117,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[164.0,
#      235.0,
#      173.0,
#      236.0,
#      176.0,
#      247.0,
#      168.0,
#      249.0,
#      160.0,
#      242.0]],
#    'area': 0,
#    'bbox': [160.0, 235.0, 16.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 118,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[177.0,
#      246.0,
#      186.0,
#      247.0,
#      189.0,
#      252.0,
#      183.0,
#      260.0,
#      175.0,
#      257.0]],
#    'area': 0,
#    'bbox': [175.0, 246.0, 14.0, 14.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 119,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[186.0,
#      257.0,
#      197.0,
#      256.0,
#      201.0,
#      269.0,
#      192.0,
#      273.0,
#      185.0,
#      267.0]],
#    'area': 0,
#    'bbox': [185.0, 256.0, 16.0, 17.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 120,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[195.0,
#      272.0,
#      207.0,
#      269.0,
#      214.0,
#      271.0,
#      217.0,
#      277.0,
#      208.0,
#      279.0,
#      201.0,
#      284.0,
#      195.0,
#      281.0]],
#    'area': 0,
#    'bbox': [195.0, 269.0, 22.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 121,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[219.0,
#      279.0,
#      221.0,
#      285.0,
#      219.0,
#      291.0,
#      213.0,
#      292.0,
#      202.0,
#      291.0,
#      202.0,
#      283.0,
#      210.0,
#      281.0]],
#    'area': 0,
#    'bbox': [202.0, 279.0, 19.0, 13.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 122,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[229.0,
#      291.0,
#      231.0,
#      297.0,
#      231.0,
#      297.0,
#      227.0,
#      307.0,
#      219.0,
#      305.0,
#      213.0,
#      294.0,
#      220.0,
#      293.0,
#      222.0,
#      287.0]],
#    'area': 0,
#    'bbox': [213.0, 287.0, 18.0, 20.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 123,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[233.0,
#      299.0,
#      239.0,
#      301.0,
#      241.0,
#      311.0,
#      241.0,
#      311.0,
#      235.0,
#      317.0,
#      227.0,
#      313.0,
#      229.0,
#      303.0]],
#    'area': 0,
#    'bbox': [227.0, 299.0, 14.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 124,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[250.0,
#      310.0,
#      258.0,
#      320.0,
#      250.0,
#      324.0,
#      240.0,
#      325.0,
#      239.0,
#      317.0]],
#    'area': 0,
#    'bbox': [239.0, 310.0, 19.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 125,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[254.0,
#      320.0,
#      262.0,
#      321.0,
#      264.0,
#      333.0,
#      259.0,
#      338.0,
#      253.0,
#      335.0,
#      249.0,
#      327.0]],
#    'area': 0,
#    'bbox': [249.0, 320.0, 15.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 126,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[267.0,
#      333.0,
#      280.0,
#      334.0,
#      282.0,
#      343.0,
#      273.0,
#      348.0,
#      266.0,
#      346.0,
#      261.0,
#      339.0]],
#    'area': 0,
#    'bbox': [261.0, 333.0, 21.0, 15.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 127,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[130.0,
#      255.0,
#      137.0,
#      259.0,
#      133.0,
#      267.0,
#      129.0,
#      273.0,
#      121.0,
#      269.0,
#      122.0,
#      260.0]],
#    'area': 0,
#    'bbox': [121.0, 255.0, 16.0, 18.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 128,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[139.0,
#      263.0,
#      148.0,
#      264.0,
#      148.0,
#      270.0,
#      144.0,
#      276.0,
#      139.0,
#      282.0,
#      134.0,
#      278.0,
#      134.0,
#      265.0]],
#    'area': 0,
#    'bbox': [134.0, 263.0, 14.0, 19.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 129,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[147.0, 273.0, 154.0, 281.0, 152.0, 285.0, 141.0, 282.0]],
#    'area': 0,
#    'bbox': [141.0, 273.0, 13.0, 12.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 130,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[154.0,
#      284.0,
#      164.0,
#      283.0,
#      164.0,
#      294.0,
#      159.0,
#      302.0,
#      151.0,
#      304.0,
#      150.0,
#      297.0]],
#    'area': 0,
#    'bbox': [150.0, 283.0, 14.0, 21.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 131,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[167.0,
#      296.0,
#      174.0,
#      297.0,
#      178.0,
#      301.0,
#      173.0,
#      312.0,
#      171.0,
#      318.0,
#      159.0,
#      309.0,
#      163.0,
#      302.0]],
#    'area': 0,
#    'bbox': [159.0, 296.0, 19.0, 22.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 132,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[181.0,
#      310.0,
#      187.0,
#      310.0,
#      187.0,
#      320.0,
#      179.0,
#      326.0,
#      172.0,
#      322.0,
#      173.0,
#      314.0]],
#    'area': 0,
#    'bbox': [172.0, 310.0, 15.0, 16.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 133,
#    'image_id': 1,
#    'category_id': 1,
#    'segmentation': [[204.0,
#      326.0,
#      210.0,
#      333.0,
#      205.0,
#      339.0,
#      196.0,
#      336.0,
#      196.0,
#      329.0]],
#    'area': 0,
#    'bbox': [196.0, 326.0, 14.0, 13.0],
# ...
#      337.0,
#      472.0,
#      328.0,
#      470.0,
#      322.0,
#      475.0,
#      320.0,
#      485.0,
#      313.0,
#      492.841,
#      313.953,
#      501.0,
#      319.0,
#      508.0,
#      320.0,
#      509.0,
#      325.0,
#      511.0,
#      327.0,
#      508.0,
#      329.0,
#      511.0,
#      332.0,
#      511.0,
#      337.0,
#      508.0,
#      343.0,
#      505.0,
#      343.0,
#      507.0,
#      347.0,
#      504.0,
#      350.0,
#      500.0,
#      351.0,
#      499.0,
#      349.0,
#      498.0,
#      350.0]],
#    'area': 0,
#    'bbox': [469.0, 313.0, 42.0, 40.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 975,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[502.983,
#      443.411,
#      497.0,
#      448.0,
#      490.0,
#      445.0,
#      476.0,
#      434.0,
#      476.29,
#      429.773,
#      482.0,
#      426.0,
#      491.0,
#      414.0,
#      494.0,
#      409.0,
#      497.855,
#      408.325,
#      510.0,
#      411.0,
#      518.0,
#      423.0,
#      513.0,
#      429.0,
#      516.0,
#      430.0,
#      516.0,
#      434.0,
#      513.0,
#      440.0,
#      513.0,
#      444.0,
#      511.0,
#      444.0,
#      508.0,
#      446.0]],
#    'area': 0,
#    'bbox': [476.0, 408.325, 42.0, 39.67500000000001],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 976,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[508.0,
#      534.0,
#      502.068,
#      533.748,
#      497.0,
#      534.0,
#      488.232,
#      531.468,
#      487.0,
#      522.0,
#      485.952,
#      514.286,
#      491.0,
#      506.0,
#      500.0,
#      506.0,
#      505.0,
#      503.0,
#      507.0,
#      508.0,
#      508.0,
#      512.0,
#      514.0,
#      513.0,
#      519.0,
#      513.0,
#      519.0,
#      517.0,
#      522.0,
#      518.0,
#      521.0,
#      523.0,
#      516.0,
#      527.0,
#      512.0,
#      527.0]],
#    'area': 0,
#    'bbox': [485.952, 503.0, 36.048, 31.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 977,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[590.0,
#      460.0,
#      587.0,
#      457.0,
#      583.0,
#      457.0,
#      577.0,
#      453.0,
#      574.0,
#      453.0,
#      572.0,
#      443.0,
#      570.0,
#      440.0,
#      571.0,
#      431.0,
#      580.0,
#      426.0,
#      583.303,
#      423.536,
#      593.0,
#      425.0,
#      597.0,
#      426.0,
#      602.0,
#      432.0,
#      605.0,
#      432.0,
#      606.0,
#      435.0,
#      603.0,
#      444.0,
#      605.0,
#      455.0,
#      595.0,
#      460.0]],
#    'area': 0,
#    'bbox': [570.0, 423.536, 36.0, 36.464],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 978,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[584.0,
#      557.0,
#      574.581,
#      548.356,
#      570.278,
#      537.413,
#      576.0,
#      532.0,
#      577.655,
#      519.709,
#      584.0,
#      516.0,
#      587.0,
#      513.0,
#      594.0,
#      517.0,
#      601.0,
#      518.0,
#      603.0,
#      524.0,
#      609.0,
#      525.0,
#      614.0,
#      531.0,
#      614.0,
#      537.0,
#      609.0,
#      544.0,
#      605.0,
#      546.0,
#      601.0,
#      550.0,
#      600.0,
#      548.0,
#      598.0,
#      550.0,
#      597.0,
#      553.0,
#      594.0,
#      555.0,
#      592.0,
#      555.0,
#      589.0,
#      558.0,
#      586.0,
#      557.0]],
#    'area': 0,
#    'bbox': [570.278, 513.0, 43.72199999999998, 45.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 979,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[685.0,
#      477.0,
#      678.0,
#      473.0,
#      673.036,
#      473.945,
#      665.0,
#      467.0,
#      661.294,
#      458.114,
#      664.0,
#      448.0,
#      668.286,
#      445.977,
#      671.0,
#      440.0,
#      679.0,
#      439.0,
#      688.0,
#      445.0,
#      690.0,
#      448.0,
#      695.0,
#      448.0,
#      703.0,
#      455.0,
#      703.0,
#      461.0,
#      699.0,
#      467.0,
#      698.0,
#      470.0,
#      693.0,
#      471.0,
#      692.0,
#      475.0,
#      689.0,
#      475.0]],
#    'area': 0,
#    'bbox': [661.294, 439.0, 41.70600000000002, 38.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 980,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[693.0,
#      568.0,
#      685.0,
#      570.0,
#      674.0,
#      565.0,
#      664.0,
#      556.0,
#      663.0,
#      543.0,
#      670.793,
#      538.719,
#      685.0,
#      533.0,
#      696.0,
#      535.0,
#      704.0,
#      549.0,
#      703.0,
#      557.0,
#      701.0,
#      561.0,
#      697.0,
#      561.0,
#      695.0,
#      562.0]],
#    'area': 0,
#    'bbox': [663.0, 533.0, 41.0, 37.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 981,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[755.0,
#      483.0,
#      752.0,
#      483.0,
#      745.0,
#      474.0,
#      746.0,
#      466.0,
#      753.0,
#      458.0,
#      760.0,
#      452.0,
#      775.0,
#      450.0,
#      776.0,
#      455.0,
#      783.0,
#      457.0,
#      790.0,
#      461.0,
#      790.0,
#      470.0,
#      789.0,
#      476.0,
#      788.0,
#      479.0,
#      788.0,
#      486.0,
#      782.0,
#      489.0,
#      776.0,
#      488.0,
#      776.0,
#      491.0,
#      772.0,
#      492.0,
#      763.0,
#      487.0,
#      762.0,
#      484.0,
#      757.0,
#      485.0]],
#    'area': 0,
#    'bbox': [745.0, 450.0, 45.0, 42.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 982,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[782.0,
#      583.0,
#      767.0,
#      582.0,
#      765.0,
#      576.0,
#      761.0,
#      576.0,
#      758.0,
#      573.0,
#      757.0,
#      568.0,
#      757.0,
#      563.0,
#      760.0,
#      556.0,
#      761.0,
#      545.0,
#      767.0,
#      544.0,
#      771.0,
#      543.0,
#      774.0,
#      539.0,
#      780.0,
#      542.0,
#      786.0,
#      548.0,
#      791.0,
#      552.0,
#      793.0,
#      554.0,
#      793.0,
#      555.0,
#      798.0,
#      561.0,
#      800.0,
#      564.0,
#      800.0,
#      569.0,
#      799.0,
#      573.0,
#      795.0,
#      575.0,
#      793.0,
#      579.0,
#      789.0,
#      580.0,
#      786.0,
#      583.0]],
#    'area': 0,
#    'bbox': [757.0, 539.0, 43.0, 44.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 983,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[874.0,
#      502.0,
#      868.0,
#      503.0,
#      860.0,
#      503.0,
#      854.0,
#      505.0,
#      845.0,
#      497.0,
#      840.0,
#      498.0,
#      841.0,
#      490.0,
#      844.0,
#      474.0,
#      849.0,
#      471.0,
#      852.633,
#      468.583,
#      871.0,
#      467.0,
#      874.0,
#      472.0,
#      879.0,
#      475.0,
#      882.0,
#      493.0,
#      881.0,
#      499.0,
#      877.0,
#      504.0]],
#    'area': 0,
#    'bbox': [840.0, 467.0, 42.0, 38.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 984,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[872.446,
#      590.288,
#      856.348,
#      588.342,
#      844.673,
#      569.768,
#      862.539,
#      556.854,
#      876.691,
#      568.883,
#      883.413,
#      574.19]],
#    'area': 0,
#    'bbox': [844.673, 556.854, 38.74000000000001, 33.43399999999997],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 985,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[964.0,
#      519.0,
#      954.0,
#      520.0,
#      947.0,
#      521.0,
#      940.0,
#      517.0,
#      942.0,
#      515.0,
#      936.0,
#      512.0,
#      929.0,
#      500.0,
#      936.0,
#      482.0,
#      941.0,
#      483.0,
#      950.0,
#      483.0,
#      958.0,
#      483.0,
#      967.726,
#      488.48,
#      972.0,
#      493.0,
#      967.0,
#      496.0,
#      972.0,
#      499.0,
#      974.0,
#      503.0,
#      972.0,
#      512.0]],
#    'area': 0,
#    'bbox': [929.0, 482.0, 45.0, 39.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 986,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[956.0,
#      613.0,
#      947.415,
#      609.565,
#      943.0,
#      608.0,
#      942.0,
#      603.0,
#      937.0,
#      601.0,
#      932.0,
#      599.0,
#      933.0,
#      593.0,
#      935.0,
#      591.0,
#      935.0,
#      580.0,
#      942.0,
#      577.0,
#      946.0,
#      572.0,
#      951.0,
#      573.0,
#      958.0,
#      570.0,
#      962.0,
#      571.0,
#      964.0,
#      575.0,
#      966.0,
#      576.0,
#      967.0,
#      582.0,
#      970.0,
#      584.0,
#      973.0,
#      584.0,
#      976.0,
#      582.0,
#      982.0,
#      587.0,
#      984.0,
#      593.0,
#      981.0,
#      597.0,
#      979.0,
#      599.0,
#      975.0,
#      605.0,
#      972.0,
#      607.0,
#      970.0,
#      609.0,
#      967.0,
#      611.0,
#      963.0,
#      610.0,
#      959.0,
#      610.0]],
#    'area': 0,
#    'bbox': [932.0, 570.0, 52.0, 43.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 987,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[522.0,
#      724.0,
#      512.0,
#      728.0,
#      505.0,
#      723.0,
#      498.0,
#      719.0,
#      491.844,
#      708.022,
#      493.0,
#      703.0,
#      493.0,
#      692.0,
#      501.0,
#      693.0,
#      509.0,
#      693.0,
#      513.0,
#      690.0,
#      523.0,
#      694.0,
#      528.0,
#      693.0,
#      537.0,
#      703.0,
#      537.0,
#      710.0,
#      536.0,
#      715.0,
#      531.0,
#      715.0,
#      528.0,
#      719.0]],
#    'area': 0,
#    'bbox': [491.844, 690.0, 45.156000000000006, 38.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 988,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[606.0,
#      742.0,
#      596.665,
#      734.847,
#      592.0,
#      732.0,
#      594.0,
#      714.0,
#      603.0,
#      706.0,
#      616.501,
#      708.473,
#      620.0,
#      711.0,
#      621.0,
#      719.0,
#      620.0,
#      727.0,
#      613.0,
#      737.0]],
#    'area': 0,
#    'bbox': [592.0, 706.0, 29.0, 36.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 989,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[605.0,
#      645.0,
#      599.0,
#      647.0,
#      591.0,
#      645.0,
#      584.0,
#      638.0,
#      581.138,
#      616.475,
#      586.0,
#      612.0,
#      592.0,
#      613.0,
#      596.0,
#      609.0,
#      601.0,
#      611.0,
#      612.614,
#      616.67,
#      617.697,
#      625.468,
#      620.0,
#      629.0,
#      616.0,
#      637.0]],
#    'area': 0,
#    'bbox': [581.138, 609.0, 38.861999999999966, 38.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 990,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[689.0,
#      661.0,
#      688.0,
#      658.0,
#      681.0,
#      658.0,
#      674.875,
#      652.858,
#      670.0,
#      631.0,
#      675.0,
#      629.0,
#      679.0,
#      621.0,
#      684.0,
#      621.0,
#      693.0,
#      623.0,
#      700.0,
#      623.0,
#      710.0,
#      633.0,
#      712.0,
#      646.0,
#      709.0,
#      655.0,
#      703.0,
#      659.0,
#      697.0,
#      660.0,
#      692.0,
#      662.0]],
#    'area': 0,
#    'bbox': [670.0, 621.0, 42.0, 41.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 991,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[702.0,
#      756.0,
#      699.0,
#      753.0,
#      693.0,
#      753.0,
#      688.0,
#      749.0,
#      681.046,
#      728.672,
#      685.0,
#      722.0,
#      687.0,
#      716.0,
#      697.0,
#      716.0,
#      702.0,
#      715.0,
#      704.0,
#      720.0,
#      713.488,
#      721.267,
#      714.0,
#      727.0,
#      721.0,
#      730.0,
#      726.0,
#      737.0,
#      721.0,
#      744.0,
#      713.0,
#      749.0]],
#    'area': 0,
#    'bbox': [681.046, 715.0, 44.95399999999995, 41.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 992,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[784.0,
#      675.0,
#      776.0,
#      675.0,
#      767.0,
#      672.0,
#      766.0,
#      665.0,
#      762.0,
#      659.0,
#      762.0,
#      651.0,
#      765.0,
#      644.0,
#      770.0,
#      640.0,
#      775.0,
#      641.0,
#      782.0,
#      635.0,
#      791.0,
#      639.0,
#      799.0,
#      650.0,
#      800.0,
#      665.0,
#      802.0,
#      674.0,
#      797.0,
#      674.0,
#      793.0,
#      672.0,
#      787.0,
#      676.0]],
#    'area': 0,
#    'bbox': [762.0, 635.0, 40.0, 41.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 993,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[795.0,
#      769.0,
#      784.0,
#      769.0,
#      776.0,
#      763.0,
#      766.0,
#      754.0,
#      767.0,
#      747.0,
#      767.0,
#      742.0,
#      768.0,
#      737.0,
#      773.0,
#      734.0,
#      775.0,
#      734.0,
#      780.0,
#      728.0,
#      794.0,
#      727.0,
#      804.0,
#      731.0,
#      807.0,
#      736.0,
#      804.0,
#      738.0,
#      809.0,
#      748.0,
#      813.0,
#      757.0,
#      809.0,
#      758.0,
#      808.0,
#      762.0,
#      805.0,
#      766.0,
#      800.0,
#      765.0,
#      799.0,
#      768.0]],
#    'area': 0,
#    'bbox': [766.0, 727.0, 47.0, 42.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 994,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[889.0,
#      688.0,
#      876.0,
#      693.0,
#      873.0,
#      688.0,
#      869.0,
#      690.0,
#      858.0,
#      683.0,
#      856.0,
#      677.0,
#      852.0,
#      675.0,
#      856.0,
#      664.0,
#      859.0,
#      653.0,
#      868.0,
#      658.0,
#      871.0,
#      653.0,
#      880.0,
#      655.0,
#      891.0,
#      661.0,
#      895.0,
#      668.0,
#      893.0,
#      678.0]],
#    'area': 0,
#    'bbox': [852.0, 653.0, 43.0, 40.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 995,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[887.0,
#      778.0,
#      882.0,
#      783.0,
#      871.0,
#      779.0,
#      863.0,
#      766.0,
#      863.0,
#      759.0,
#      863.0,
#      747.0,
#      875.0,
#      743.0,
#      879.0,
#      746.0,
#      884.0,
#      747.0,
#      888.408,
#      747.609,
#      894.035,
#      753.383,
#      899.0,
#      756.0,
#      899.809,
#      764.192,
#      892.0,
#      778.0]],
#    'area': 0,
#    'bbox': [863.0, 743.0, 36.80899999999997, 40.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 996,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[976.0,
#      700.0,
#      966.0,
#      702.0,
#      961.0,
#      704.0,
#      944.0,
#      699.0,
#      943.0,
#      688.0,
#      953.0,
#      669.0,
#      960.0,
#      672.0,
#      963.0,
#      669.0,
#      971.0,
#      671.0,
#      972.0,
#      677.0,
#      977.257,
#      681.317,
#      977.0,
#      689.0,
#      981.0,
#      694.0]],
#    'area': 0,
#    'bbox': [943.0, 669.0, 38.0, 35.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 997,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[995.0,
#      779.0,
#      997.0,
#      782.0,
#      995.0,
#      795.0,
#      983.0,
#      802.0,
#      978.242,
#      798.802,
#      969.0,
#      800.0,
#      960.0,
#      794.0,
#      957.0,
#      788.0,
#      951.0,
#      784.0,
#      945.0,
#      772.0,
#      952.0,
#      766.0,
#      956.0,
#      758.0,
#      963.535,
#      755.683,
#      966.0,
#      759.0,
#      972.0,
#      756.0,
#      976.0,
#      756.0,
#      981.0,
#      762.0,
#      989.0,
#      769.0,
#      997.0,
#      773.0]],
#    'area': 0,
#    'bbox': [945.0, 755.683, 52.0, 46.31700000000001],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 998,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[530.0,
#      820.0,
#      521.0,
#      818.0,
#      514.0,
#      819.0,
#      507.0,
#      810.0,
#      498.0,
#      799.0,
#      498.0,
#      791.0,
#      502.0,
#      781.0,
#      516.0,
#      777.0,
#      522.0,
#      779.0,
#      532.0,
#      781.0,
#      538.502,
#      797.996,
#      539.0,
#      806.0,
#      535.0,
#      808.0]],
#    'area': 0,
#    'bbox': [498.0, 777.0, 41.0, 43.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 999,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[530.0,
#      914.0,
#      516.522,
#      914.357,
#      509.0,
#      910.0,
#      506.22,
#      903.46,
#      503.0,
#      895.0,
#      508.597,
#      881.27,
#      510.0,
#      879.0,
#      514.0,
#      878.0,
#      517.0,
#      876.0,
#      522.0,
#      871.0,
#      533.0,
#      874.0,
#      540.0,
#      875.0,
#      543.0,
#      884.0,
#      547.0,
#      887.0,
#      548.0,
#      896.0,
#      546.0,
#      900.0,
#      542.0,
#      901.0,
#      544.0,
#      905.0,
#      537.0,
#      909.0,
#      532.0,
#      909.0]],
#    'area': 0,
#    'bbox': [503.0, 871.0, 45.0, 43.35699999999997],
#    'iscrowd': 0,
#    'score': 1.0},
#   {'id': 1000,
#    'image_id': 7,
#    'category_id': 1,
#    'segmentation': [[550.0,
#      1002.0,
#      540.0,
#      1002.0,
#      537.0,
#      1006.0,
#      528.409,
#      1005.89,
#      521.0,
#      1003.0,
#      519.0,
#      994.0,
#      512.0,
#      989.0,
#      514.0,
#      982.0,
#      518.0,
#      977.0,
#      516.0,
#      973.0,
#      517.0,
#      966.0,
#      523.0,
#      966.0,
#      529.0,
#      963.0,
#      544.0,
#      967.0,
#      542.0,
#      972.0,
#      546.0,
#      978.0,
#      549.0,
#      984.0,
#      553.0,
#      987.0,
#      554.0,
#      990.0,
#      554.0,
#      994.0,
#      552.0,
#      995.0,
#      550.0,
#      997.0]],
#    'area': 0,
#    'bbox': [512.0, 963.0, 42.0, 43.0],
#    'iscrowd': 0,
#    'score': 1.0},
#   ...],
#  'categories': [{'id': 1, 'name': 'individual_tree', 'supercategory': 'tree'},
#   {'id': 2, 'name': 'group_of_trees', 'supercategory': 'tree'}]}

# %% [markdown]
# ### Helper: normalize polygon pairs
# - COCO polygon segmentations are flat lists of pixel coordinates: [x1, y1, x2, y2, …].
#
# - YOLO wants normalized coordinates (divide by image width/height).
#
# - This generator yields normalized (x, y) pairs ready to be written.
#
# #### Process
#
# - Takes a flat list of coordinates: [x1, y1, x2, y2, ...]
#
# - Groups them into (x, y) pairs using zip(it, it)
#
# - Divides each coordinate by the image width (w) and height (h) to normalize them between 0 and 1
#
# - This is standard in YOLO and most deep learning frameworks — so coordinates are relative, not pixel-based.

# %%
def norm_pair_iter(coords, w, h):
    """Yield (x,y) normalized to [0,1] from a flat list of pixel coords."""
    it = iter(coords)            # coords like [x1,y1,x2,y2,...]
    for x, y in zip(it, it):     # step through pairs
        yield (float(x)/w, float(y)/h)

# %% [markdown]
# ### Helper: decide which split an image belongs to
#
# - We look for the image file under each split’s images/.
#
# - Whatever split contains the image determines where we write the label file.
#
# - This lets you reuse a single COCO file for all splits.

# %%
def find_split_for_file(filename):
    """Return 'train'/'valid'/'test' if the image exists in that split, else None."""
    for s in SPLITS:
        p = os.path.join(ROOT, s, "images", filename)
        if os.path.exists(p):
            return s
    return None

# %% [markdown]
# ### main() – the pipeline
#
# - Safety check + load the COCO dict. The standard COCO structure is:
#
#     - images: list of image dicts (id, file_name, width, height, …)
#
#     - annotations: list of annotation dicts (image_id, category_id, bbox, segmentation, …)
#
#     - categories: list of category dicts (id, name, …)

# %%
def main():
    if not os.path.exists(COCO_JSON):
        sys.exit(f"COCO file not found: {COCO_JSON}")

    with open(COCO_JSON, "r") as f:
        coco = json.load(f)

# %% [markdown]
# ### Build fast lookups & category mapping
#
# - Why mapping? COCO category_id numbers are often not 0..N-1. YOLO expects classes to be 0..nc-1.
#
# - We sort the COCO category ids, then assign 0,1,2,… accordingly.
#
# - names keeps the readable class names in that order.
#
# (You’ll often also build anns_by_img = defaultdict(list) and fill it by iterating over coco["annotations"] so you can fetch annotations per image fast.)

# %%
# id -> image dict (quick access)
images_by_id = {img["id"]: img for img in coco.get("images", [])}

# map arbitrary COCO category ids to contiguous [0..nc-1]
cat_ids_sorted = sorted(c["id"] for c in coco.get("categories", []))
cat_to_yolo = {cid: i for i, cid in enumerate(cat_ids_sorted)}

# list of class names, ordered by the mapping above (for data.yaml later)
names = [next(c["name"] for c in coco["categories"] if c["id"] == cid)
         for cid in cat_ids_sorted]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # id -> image dict (quick access)
# ----> 2 images_by_id = {img["id"]: img for img in coco.get("images", [])}
#       4 # map arbitrary COCO category ids to contiguous [0..nc-1]
#       5 cat_ids_sorted = sorted(c["id"] for c in coco.get("categories", []))
#
# NameError: name 'coco' is not defined

# %% [markdown]
# ### Make sure labels/ folders exist
#
# YOLO expects one .txt file per image in a sibling labels/ folder.
#
# This creates:
#
#
# data/model-data/
#   ├── train/
#   │   ├── images/
#   │   └── labels/
#   ├── valid/
#   │   ├── images/
#   │   └── labels/
#   └── test/
#       ├── images/
#       └── labels/

# %%
for s in SPLITS:
    os.makedirs(os.path.join(ROOT, s, "labels"), exist_ok=True)

# %% [markdown]
# ### Iterate images → write labels
#
# (You’ll see this in the lower part of the script)
#
# - COCO bbox = [x_min, y_min, width, height] (pixels)
#
# - YOLO bbox = class cx cy w h normalized to 0..1 (center-based)
#
# - YOLOv8 segmentation = class x1 y1 x2 y2 … (normalized, one polygon per line)
#
# Typical loop structure:

# %%
counts = defaultdict(int)  # stats

# optional: group annotations by image id for speed
annotations_by_img = defaultdict(list)
for annotation in coco.get("annotations", []):
    annotations_by_img[annotation["image_id"]].append(annotation)

for img in coco.get("images", []):
    filename = img["file_name"]
    w, h     = img["width"], img["height"]

    split = find_split_for_file(filename)
    if split is None:
        counts["skipped_no_split"] += 1
        continue

    label_path = os.path.join(ROOT, split, "labels",
                              os.path.splitext(filename)[0] + ".txt")

    lines = []  # lines to write for this image

    for annotation in annotations_by_img.get(img["id"], []):
        # skip crowd/RLE etc if you only want polygons or bboxes
        if annotation.get("iscrowd", 0) == 1:
            counts["skipped_crowd"] += 1
            continue

        categoryid = annotation["category_id"]
        cls = cat_to_yolo[categoryid]  # contiguous class id

        # # ---- Option A: bbox → YOLO box ----
        # if "bbox" in annotation and annotation["bbox"]:
        #     x, y, bw, bh = annotation["bbox"]         # COCO = top-left + width/height
        #     xc = (x + bw / 2.0) / w            # YOLO needs center-x, center-y, w, h
        #     yc = (y + bh / 2.0) / h
        #     ww = bw / w
        #     hh = bh / h

        #     # clip to [0,1] just in case
        #     xc = min(max(xc, 0), 1); yc = min(max(yc, 0), 1)
        #     ww = min(max(ww, 0), 1); hh = min(max(hh, 0), 1)

        #     lines.append(f"{cls} {xc:.6f} {yc:.6f} {ww:.6f} {hh:.6f}")



        # ---- Option B: polygon segmentations → YOLOv8 segmentation ----
        # YOLOv8 expects: cls x1 y1 x2 y2 ... (normalized), one polygon per line
        segmentations = annotation.get("segmentations", [])
        if segmentations and isinstance(segmentations, list):   # skip RLE (dict) here
            for segmentation in segmentations:
                if len(segmentation) >= 6 and len(segmentation) % 2 == 0:
                    pts = [f"{x:.6f} {y:.6f}" for x, y in norm_pair_iter(segmentation, w, h)]
                    lines.append(f"{cls} " + " ".join(pts))
                else:
                    counts["skipped_bad_seg"] += 1

    # write all objects for this image
    with open(label_path, "w") as f:
        f.write("\n".join(lines))

    counts["images_processed"] += 1

# (Optional) Print summary, write data.yaml using `names` etc.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       3 # optional: group annotations by image id for speed
#       4 anns_by_img = defaultdict(list)
# ----> 5 for ann in coco.get("annotations", []):
#       6     anns_by_img[ann["image_id"]].append(ann)
#       8 for img in coco.get("images", []):
#
# NameError: name 'coco' is not defined

# %% [markdown]
# ### Why this structure works well
#
# - Split detection via find_split_for_file lets you use one COCO file for all splits.
#
# - Contiguous class ids guarantee YOLO training scripts don’t choke on sparse ids.
#
# - One label file per image matches Ultralytics’ expected structure.
#
# - Normalization is done once and always with actual image width/height.
#
# - Polygon → YOLOv8 handled by norm_pair_iter.

# %%
# Out:
# {'path': '/Users/mitchellpalmer/Projects/solafune-canopy-capstone-clean/data/model-data', 'train': 'data/model-data/train/images', 'val': 'data/model-data/valid/images', 'test': 'data/model-data/test/images', 'names': ['individual_tree', 'group_of_trees']}
